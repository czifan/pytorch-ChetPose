# %%
import os
import cv2
import math
import json
import torch
from torch.utils.data import DataLoader
import random
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('..')
from config import config
from utils import display_one_img
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-495db20abaee> in <module>
#      11 sys.path.append('..')
#      12 from config import config
# ---> 13 from utils import display_one_img
#
# ~\Desktop\ChetPose\chetpose\utils.py in <module>
#       4 import yaml
#       5 import numpy as np
# ----> 6 from easydict import EasyDict as edict
#       7
#       8 def save_model(state, checkpoint, filename):
#
# ModuleNotFoundError: No module named 'easydict'

# %%
data = 'lsp'
split = 'val'
data_dir = os.path.join(os.getcwd(), '..', 'data')
ann_file = os.path.join(data_dir, '{}_{}.json'.format(data, split))
img_dir = os.path.join(data_dir, 'images')
json_data, img_dir
# Out:
# ('C:\\Users\\CZiFan\\Desktop\\Real-time Heatmap with regression pose estimation\\notebook\\..\\data\\lsp_val.json',
#  'C:\\Users\\CZiFan\\Desktop\\Real-time Heatmap with regression pose estimation\\notebook\\..\\data\\images')

# %%
fp = open(ann_file)
data = json.load(fp)
fp.close()
print('Image Num: ', len(data))
# Out:
# Image Num:  1000

# %%
idx = random.randint(0, len(data)-1)
img_path = os.path.join(img_dir, data[idx]['filename'])
keypoints = data[idx]['keypoints']
img = np.array(cv2.imread(img_path), dtype=np.float32)
print(img_path)
implot = plt.imshow(img[:,:,[2,1,0]] / 256., alpha=0.5)
display_one_img(plt, keypoints, cfg.limbSeq, cfg.colors)
# Out:
# C:\Users\CZiFan\Desktop\Real-time Heatmap with regression pose estimation\notebook\..\data\images\im1417.jpg
